# %% [markdown]
# <a href="https://colab.research.google.com/github/MayureshOP-max/DataAnalytics/blob/main/Assignment_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Data
data = {
    'ord_no': [70001.0, np.nan, 70002.0, 70004.0, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, 70013.0],
    'purch_amt': [150.50, 270.65, 65.26, 110.50, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, 3045.60],
    'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
    'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    'salesman_id': [5002.0, 5003.0, 5001.0, np.nan, 5002.0, 5001.0, 5001.0, np.nan, 5003.0, 5002.0, 5003.0, np.nan]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display DataFrame
print(df)
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN

# %% [markdown]
# # **1. Write a Pandas program to detect missing values of a given DataFrame.Display True or False.**

# %%
df.isnull()
# Out:
#     ord_no  purch_amt  ord_date  customer_id  salesman_id
# 0    False      False     False        False        False
# 1     True      False     False        False        False
# 2    False      False      True        False        False
# 3    False      False     False        False         True
# 4     True      False     False        False        False
# 5    False      False     False        False        False
# 6     True      False     False        False        False
# 7    False      False     False        False         True
# 8    False      False     False        False        False
# 9    False      False     False        False        False
# 10    True      False     False        False        False
# 11   False      False     False        False         True

# %% [markdown]
# # **2. Write a Pandas program to identify the column(s) of a given DataFrame which have at least one missing value.**

# %%
df.isnull().any()
# Out:
# ord_no          True
# purch_amt      False
# ord_date        True
# customer_id    False
# salesman_id     True
# dtype: bool

# %% [markdown]
# # **3. Write a Pandas program to count the number of missing values in each column of a given DataFrame.**

# %%
df.isnull().sum()
# Out:
# ord_no         4
# purch_amt      0
# ord_date       1
# customer_id    0
# salesman_id    3
# dtype: int64

# %% [markdown]
# # **4. Write a Pandas program to find and replace the missing values in a given DataFrame which do not have any valuable information.**

# %%
import pandas as pd
from io import StringIO

# CSV data as a string
data1 = """ord_no,purch_amt,ord_date,customer_id,salesman_id
70001,150.5,?,3002,5002
NaN,270.65,2012-09-10,3001,5003
70002,65.26,NaN,3001,?
70004,110.5,2012-08-17,3003,5001
NaN,948.5,2012-09-10,3002,NaN
70005,2400.6,2012-07-27,3001,5002
--,5760,2012-09-10,3001,5001
70010,?,2012-10-10,3004,?
70003,12.43,2012-10-10,--,5003
70012,2480.4,2012-06-27,3002,5002
NaN,250.45,2012-08-17,3001,5003
70013,3045.6,2012-04-25,3001,NaN
"""

# Create DataFrame
df1 = pd.read_csv(StringIO(data1))

# Display the DataFrame
print(df1)
# Out:
#    ord_no purch_amt    ord_date customer_id salesman_id
# 0   70001     150.5           ?        3002        5002
# 1     NaN    270.65  2012-09-10        3001        5003
# 2   70002     65.26         NaN        3001           ?
# 3   70004     110.5  2012-08-17        3003        5001
# 4     NaN     948.5  2012-09-10        3002         NaN
# 5   70005    2400.6  2012-07-27        3001        5002
# 6      --      5760  2012-09-10        3001        5001
# 7   70010         ?  2012-10-10        3004           ?
# 8   70003     12.43  2012-10-10          --        5003
# 9   70012    2480.4  2012-06-27        3002        5002
# 10    NaN    250.45  2012-08-17        3001        5003
# 11  70013    3045.6  2012-04-25        3001         NaN

# %%
x =df1.replace(['--','?'], np.nan, inplace=True)
print(x)
# Out:
# None

# %% [markdown]
# # **5. Write a Pandas program to drop the rows where at least one element is missing in a given DataFrame.**

# %%
x =df1.dropna()
x
# Out:
#   ord_no purch_amt    ord_date customer_id salesman_id
# 3  70004     110.5  2012-08-17        3003        5001
# 5  70005    2400.6  2012-07-27        3001        5002
# 9  70012    2480.4  2012-06-27        3002        5002

# %% [markdown]
# # **6. Write a Pandas program to drop the columns where at least one element is missing in a given DataFrame.**

# %%
df.dropna(axis=1)
# Out:
#     purch_amt  customer_id
# 0      150.50         3002
# 1      270.65         3001
# 2       65.26         3001
# 3      110.50         3003
# 4      948.50         3002
# 5     2400.60         3001
# 6     5760.00         3001
# 7     1983.43         3004
# 8     2480.40         3003
# 9      250.45         3002
# 10      75.29         3001
# 11    3045.60         3001

# %% [markdown]
# # **7. Write a Pandas program to drop the rows where all elements are missing in a given DataFrame.**

# %%
data2 = {
    'ord_no': [None, None, 70002.0, 70004.0, None, 70005.0, None, 70010.0, 70003.0, 70012.0, None, 70013.0],
    'purch_amt': [None, 270.65, 65.26, 110.50, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, 3045.60],
    'ord_date': [None, '2012-09-10', None, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
    'customer_id': [None, 3001.0, 3001.0, 3003.0, 3002.0, 3001.0, 3001.0, 3004.0, 3003.0, 3002.0, 3001.0, 3001.0]
}

df2 = pd.DataFrame(data2)
df2
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN        None          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26        None       3001.0
# 3   70004.0     110.50  2012-08-17       3003.0
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11  70013.0    3045.60  2012-04-25       3001.0

# %%
x = df2.dropna(how = 'all')
x
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26        None       3001.0
# 3   70004.0     110.50  2012-08-17       3003.0
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11  70013.0    3045.60  2012-04-25       3001.0

# %% [markdown]
# # **8. Write a Pandas program to keep the rows with at least 2 NaN values in a given DataFrame.**

# %%
data3 = {
    'ord_no': [None, None, 70002.0, None, None, 70005.0, None, 70010.0, 70003.0, 70012.0, None, None],
    'purch_amt': [None, 270.65, 65.26, None, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, None],
    'ord_date': [None, '2012-09-10', None, None, '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', None],
    'customer_id': [None, 3001.0, 3001.0, None, 3002.0, 3001.0, 3001.0, 3004.0, 3003.0, 3002.0, 3001.0, None]
}

df3 = pd.DataFrame(data3)
df3.dropna(thresh = 2)
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26        None       3001.0
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0

# %% [markdown]
# # **9. Write a Pandas program to drop those rows from a given DataFrame in which specific columns have missing values.**

# %%
data4 = {
    'ord_no': [None, None, 70002.0, None, None, 70005.0, None, 70010.0, 70003.0, 70012.0, None, None],
    'purch_amt': [None, 270.65, 65.26, None, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, None],
    'ord_date': [None, '2012-09-10', None, None, '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', None],
    'customer_id': [None, 3001.0, 3001.0, None, 3002.0, 3001.0, 3001.0, 3004.0, 3003.0, 3002.0, 3001.0, None]
}

df4 = pd.DataFrame(data4)
df4.dropna(subset =['ord_no','ord_date'])
# Out:
#     ord_no  purch_amt    ord_date  customer_id
# 5  70005.0    2400.60  2012-07-27       3001.0
# 7  70010.0    1983.43  2012-10-10       3004.0
# 8  70003.0    2480.40  2012-10-10       3003.0
# 9  70012.0     250.45  2012-06-27       3002.0

# %% [markdown]
# # **10. Write a Pandas program to keep the valid entries of a given DataFrame.**

# %%
data5= {
    'ord_no': [None, None, 70002.0, None, None, 70005.0, None, 70010.0, 70003.0, 70012.0, None],
    'purch_amt': [None, 270.65, 65.26, None, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29],
    'ord_date': [None, '2012-09-10', None, None, '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17'],
    'customer_id': [None, 3001.0, 3001.0, None, 3002.0, 3001.0, 3001.0, 3004.0, 3003.0, 3002.0, 3001.0]
}
df5 = pd.DataFrame(data5)
print(df5)
df5.dropna()
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN        None          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26        None       3001.0
# 3       NaN        NaN        None          NaN
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
#     ord_no  purch_amt    ord_date  customer_id
# 5  70005.0    2400.60  2012-07-27       3001.0
# 7  70010.0    1983.43  2012-10-10       3004.0
# 8  70003.0    2480.40  2012-10-10       3003.0
# 9  70012.0     250.45  2012-06-27       3002.0

# %% [markdown]
# # **11. Write a Pandas program to calculate the total number of missing values in a DataFrame.**

# %%
df5.isnull().sum().sum()
# Out:
# 13

# %% [markdown]
# # **12. Write a Pandas program to replace NaNs with a single constant value in specified columns in a DataFrame.**

# %%
df5['ord_no'].replace(np.nan,0,inplace=True)
df5
# Out:
# <ipython-input-15-0ef7522daedc>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df5['ord_no'].replace(np.nan,0,inplace=True)
#      ord_no  purch_amt    ord_date  customer_id
# 0       0.0        NaN        None          NaN
# 1       0.0     270.65  2012-09-10       3001.0
# 2   70002.0      65.26        None       3001.0
# 3       0.0        NaN        None          NaN
# 4       0.0     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       0.0    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      0.0      75.29  2012-08-17       3001.0

# %% [markdown]
# # **13. Write a Pandas program to replace NaNs with the value from the previous row or the next row in a given DataFrame.**

# %%
data6 = {
    'ord_no': [70001.0, None, 70002.0, 70004.0, None, 70005.0, None, 70010.0, 70003.0, 70012.0, None, 70013.0],
    'purch_amt': [150.50, None, 65.26, 110.50, 948.50, None, 5760.00, 1983.43, None, 250.45, 75.29, 3045.60],
    'sale_amt': [10.50, 20.65, None, 11.50, 98.50, None, 57.00, 19.43, None, 25.45, 75.29, 35.60],
    'ord_date': ['2012-10-05', '2012-09-10', None, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
    'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    'salesman_id': [5002.0, 5003.0, 5001.0, None, 5002.0, 5001.0, 5001.0, None, 5003.0, 5002.0, 5003.0, None]
}

df6 = pd.DataFrame(data6)
df6.fillna(method = 'ffill')
# Out:
# <ipython-input-16-e117be3652c8>:11: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df6.fillna(method = 'ffill')
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1   70001.0     150.50     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26     20.65  2012-09-10         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003       5001.0
# 4   70004.0     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0     948.50     98.50  2012-07-27         3001       5001.0
# 6   70005.0    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004       5001.0
# 8   70003.0    1983.43     19.43  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10  70012.0      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001       5003.0

# %%
df6.fillna(method = 'bfill')
# Out:
# <ipython-input-17-03fed90794a2>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df6.fillna(method = 'bfill')
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1   70002.0      65.26     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26     11.50  2012-08-17         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003       5002.0
# 4   70005.0     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0    5760.00     57.00  2012-07-27         3001       5001.0
# 6   70010.0    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004       5003.0
# 8   70003.0     250.45     25.45  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10  70013.0      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN

# %% [markdown]
# # **14. Write a Pandas program to replace NaNs with median or mean of the specified columns in a given DataFrame.**

# %%
data7 = {
    'ord_no': [70001.0, None, 70002.0, 70004.0, None, 70005.0, None, 70010.0, 70003.0, 70012.0, None, 70013.0],
    'purch_amt': [150.50, None, 65.26, 110.50, 948.50, None, 5760.00, 1983.43, None, 250.45, 75.29, 3045.60],
    'sale_amt': [10.50, 20.65, None, 11.50, 98.50, None, 57.00, 19.43, None, 25.45, 75.29, 35.60],
    # 'ord_date': ['2012-10-05', '2012-09-10', None, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
    'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    'salesman_id': [5002.0, 5003.0, 5001.0, None, 5002.0, 5001.0, 5001.0, None, 5003.0, 5002.0, 5003.0, None]
}

df7 = pd.DataFrame(data7)

df7.replace(np.nan,df7.mean())
# Out:
#       ord_no    purch_amt   sale_amt  customer_id  salesman_id
# 0   70001.00   150.500000  10.500000         3002       5002.0
# 1   70006.25  1376.614444  20.650000         3001       5003.0
# 2   70002.00    65.260000  39.324444         3001       5001.0
# 3   70004.00   110.500000  11.500000         3003       5002.0
# 4   70006.25   948.500000  98.500000         3002       5002.0
# 5   70005.00  1376.614444  39.324444         3001       5001.0
# 6   70006.25  5760.000000  57.000000         3001       5001.0
# 7   70010.00  1983.430000  19.430000         3004       5002.0
# 8   70003.00  1376.614444  39.324444         3003       5003.0
# 9   70012.00   250.450000  25.450000         3002       5002.0
# 10  70006.25    75.290000  75.290000         3001       5003.0
# 11  70013.00  3045.600000  35.600000         3001       5002.0

# %% [markdown]
# # **15. Write a Pandas program to interpolate the missing values using the LinearInterpolation method in a given DataFrame.From Wikipedia, in mathematics, linear interpolation is a method of curve fitting using linear polynomials to construct new data points within the range of a discrete set of known data points.**

# %%
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,np.nan,65.26,110.5,948.5,np.nan,5760,1983.43,np.nan,250.45, 75.29,3045.6],
'sale_amt':[10.5,20.65,np.nan,11.5,98.5,np.nan,57,19.43,np.nan,25.45, 75.29,35.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})
print("Original Orders DataFrame:")
print(df)
print("\nInterpolate the missing values using the Linear Interpolation method (purch_amt):")
df['purch_amt'].interpolate(method='linear', direction = 'forward', inplace=True)
print(df)
# Out:
# Original Orders DataFrame:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
#
# Interpolate the missing values using the Linear Interpolation method (purch_amt):
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN     107.88     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0    3354.25       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0    1116.94       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
# <ipython-input-19-1c54bf87f15d>:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['purch_amt'].interpolate(method='linear', direction = 'forward', inplace=True)

# %% [markdown]
# # **16. Write a Pandas program to count the number of missing values of a specified column in a given DataFrame.**

# %%
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,np.nan,65.26,110.5,948.5,np.nan,5760,1983.43,np.nan,250.45, 75.29,3045.6],
'sale_amt':[10.5,20.65,np.nan,11.5,98.5,np.nan,57,19.43,np.nan,25.45, 75.29,35.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})
print("Original Orders DataFrame:")
print(df)
print("\nMissing values in purch_amt column:")
result = df['purch_amt'].value_counts(dropna=False).loc[np.nan]
print(result)
# Out:
# Original Orders DataFrame:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
#
# Missing values in purch_amt column:
# 3

# %% [markdown]
# # **17. Write a Pandas program to count the missing values in a given DataFrame.**

# %%
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,np.nan,65.26,110.5,948.5,np.nan,5760,1983.43,np.nan,250.45, 75.29,3045.6],
'sale_amt':[10.5,20.65,np.nan,11.5,98.5,np.nan,57,19.43,np.nan,25.45, 75.29,35.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})
print("Original Orders DataFrame:")
print(df)
print("\nTotal missing values in a dataframe:")
tot_missing_vals = df.isnull().sum().sum()
print(tot_missing_vals)
# Out:
# Original Orders DataFrame:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
#
# Total missing values in a dataframe:
# 14

# %% [markdown]
# # **18. Write a Pandas program to find the Indexes of missing values in a given DataFrame.**

# %%
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,np.nan,65.26,110.5,948.5,np.nan,5760,1983.43,np.nan,250.45, 75.29,3045.6],
'sale_amt':[10.5,20.65,np.nan,11.5,98.5,np.nan,57,19.43,np.nan,25.45, 75.29,35.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})
print("Original Orders DataFrame:")
print(df)
print("\nMissing values in purch_amt column:")
result = df['ord_no'].isnull().to_numpy().nonzero()
print(result)
# Out:
# Original Orders DataFrame:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
#
# Missing values in purch_amt column:
# (array([ 1,  4,  6, 10]),)

# %% [markdown]
# # **19. Write a Pandas program to replace the missing values with the most frequent values present in each column of a given DataFrame.**

# %%
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,np.nan,65.26,110.5,948.5,np.nan,5760,1983.43,np.nan,250.45, 75.29,3045.6],
'sale_amt':[10.5,20.65,np.nan,11.5,98.5,np.nan,57,19.43,np.nan,25.45, 75.29,35.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})
print("Original Orders DataFrame:")
print(df)
print("\nReplace the missing values with the most frequent values present in each column:")
result = df.fillna(df.mode().iloc[0])
print(result)
# Out:
# Original Orders DataFrame:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
#
# Replace the missing values with the most frequent values present in each column:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1   70001.0      65.26     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26     10.50  2012-09-10         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003       5001.0
# 4   70001.0     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0      65.26     10.50  2012-07-27         3001       5001.0
# 6   70001.0    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004       5001.0
# 8   70003.0      65.26     10.50  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10  70001.0      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001       5001.0

# %% [markdown]
# # **20. Write a Pandas program to create a hitmap for more information about the distribution of missing values in a given DataFrame.**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,np.nan,65.26,110.5,948.5,np.nan,5760,1983.43,np.nan,250.45, 75.29,3045.6],
'sale_amt':[10.5,20.65,np.nan,11.5,98.5,np.nan,57,19.43,np.nan,25.45, 75.29,35.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})
plt.figure(figsize=(10,8))
sns.heatmap(df.isnull(), cbar=False, cmap="YlGnBu")
plt.show()
